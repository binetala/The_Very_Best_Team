# %%
#Project One APIs
# !pip install quandl
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
import matplotlib.pyplot as plt
import json
import quandl
from pprint import pprint

# %%
# csvpath = "Unemployment.csv"
# unemployment_stats_df = pd.read_csv(csvpath)
# unemployment_stats_df

# %%
unemployment_url = "https://data.colorado.gov/resource/4e3w-qire.json"
response_stats = requests.get(unemployment_url).json()
response_stats
# Out:
# [{'stateabbrv': 'CO',
#   'statename': 'Colorado',
#   'stfips': '8',
#   'areaname': 'Colorado',
#   'areatype': '1',
#   'areatyname': 'State',
#   'area': '0',
#   'periodyear': '1990',
#   'periodtype': '1',
#   'pertypdesc': 'Annual',
#   'period': '0',
#   'adjusted': '0',
#   'prelim': '0',
#   'benchmark': '2018',
#   'laborforce': '1763683',
#   'emplab': '1671823',
#   'unemp': '91860',
#   'unemprate': '5.2'},
#  {'stateabbrv': 'CO',
#   'statename': 'Colorado',
#   'stfips': '8',
#   'areaname': 'Colorado',
#   'areatype': '1',
#   'areatyname': 'State',
#   'area': '0',
#   'periodyear': '1990',
#   'periodtype': '1',
#   'pertypdesc': 'Annual',
#   'period': '0',
#   'adjusted': '1',
#   'prelim': '1',
#   'benchmark': '2018',
#   'laborforce': '1763139',
#   'emplab': '1671092',
#   'unemp': '92047',
#   'unemprate': '5.2'},
#  {'stateabbrv': 'CO',
#   'statename': 'Colorado',
#   'stfips': '8',
#   'areaname': 'Colorado',
#   'areatype': '1',
# ...
