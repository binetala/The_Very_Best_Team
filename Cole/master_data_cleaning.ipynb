# %%
import json
import time
import pandas as pd
import requests
import matplotlib.pyplot as plt
import scipy as sp
from pprint import pprint
import quandl
from config import api_key
import csv
import os

# %%
master_data_path = os.path.join("..", "..", "Master_Data")

# %%
master_data_original = pd.read_csv(master_data_path)

# %%
master_data_original.head()
# Out:
#    Year Month Year-Month  Region ID           Region Name Region Type  \
# 0  2016   Apr     2016-4     753871  Breckenridge, CO; CO       metro
# 1  2016   Apr     2016-4     753871  Breckenridge, CO; CO       metro
# 2  2016   Apr     2016-4     753871  Breckenridge, CO; CO       metro
# 3  2016   Apr     2016-4     753871  Breckenridge, CO; CO       metro
# 4  2016   Apr     2016-4     753871  Breckenridge, CO; CO       metro
#
#   Indicator ID                            Indicator Name        Value  \
# 0         Z2BR            ZHVI 2-Bedroom Time Series ($)    384,884.0
# 1         Z4BR            ZHVI 4-Bedroom Time Series ($)    881,951.0
# 2         Z5BR           ZHVI 5+ Bedroom Time Series ($)  1,287,769.0
# 3         ZATT  ZHVI All Homes- Top Tier Time Series ($)    842,653.0
# 4         Z1BR            ZHVI 1-Bedroom Time Series ($)    243,688.0
#
#   County Population  Unemployment Rate  Wells Fargo Rate  Freddie Mac Rate  \
# ...

# %%
master_data_reorg = master_data_original[["Year", "Month","Year-Month", "Date Zillow", "Date Interest", "Indicator ID", "Indicator Name", "Region ID", "Region Type", "Region Name", "Value", "County Population", "Unemployment Rate", "Wells Fargo Rate", "Freddie Mac Rate"]]

# %%
master_data_reorg.head()
# Out:
#    Year Month Year-Month Date Zillow Date Interest Indicator ID  \
# 0  2016   Apr     2016-4     4/30/16       4/28/16         Z2BR
# 1  2016   Apr     2016-4     4/30/16       4/28/16         Z4BR
# 2  2016   Apr     2016-4     4/30/16       4/28/16         Z5BR
# 3  2016   Apr     2016-4     4/30/16       4/28/16         ZATT
# 4  2016   Apr     2016-4     4/30/16       4/28/16         Z1BR
#
#                              Indicator Name  Region ID Region Type  \
# 0            ZHVI 2-Bedroom Time Series ($)     753871       metro
# 1            ZHVI 4-Bedroom Time Series ($)     753871       metro
# 2           ZHVI 5+ Bedroom Time Series ($)     753871       metro
# 3  ZHVI All Homes- Top Tier Time Series ($)     753871       metro
# 4            ZHVI 1-Bedroom Time Series ($)     753871       metro
#
#             Region Name        Value County Population  Unemployment Rate  \
# 0  Breckenridge, CO; CO    384,884.0            30,566                3.5
# ...

# %%
master_data_cleaned = master_data_reorg

# %%
master_data_cleaned.to_csv("output_data/master_data_cleaned.csv")
